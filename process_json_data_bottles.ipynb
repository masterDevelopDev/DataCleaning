# %%
import pandas as pd

# %% [markdown]
# ### Watches documents

# %%
import os

# Specify the directory you want to search
directory = r'C:\Users\delll\Downloads\metadata\ListData_Bottles'

# Initialize a list to hold all the file paths
json_files = []

# Walk through directory
for dirpath, dirnames, files in os.walk(directory):
    for file in files:
        if file.endswith(".json"):
            json_files.append(os.path.join(dirpath, file))

json_files
# Out:
# ['C:\\Users\\delll\\Downloads\\metadata\\ListData_Bottles\\ListData_Bottles.json']

# %%
list_df_bottles = []
for json_file in json_files:
    df = pd.read_json(json_file)
    df['FileLeafRef'] = df['FileLeafRef'].fillna('')
    df = df[df['FileLeafRef'].str.contains('.pdf')].drop_duplicates()
    df['FileLeafRef'] = df['FileLeafRef'].apply(lambda x: x.replace('.aspx', ''))
    list_df_bottles.append(df)

# %%
df_concatenated = pd.concat(list_df_bottles, ignore_index=True).drop_duplicates()

def change_year_format(year_str):
    if year_str:
        return int(year_str.replace(',', ''))
    else:
        return ''
    
def change_str_to_int(string):
    if string:
        return int(string)
    else:
        return 0
    
df_concatenated['AnneePublication'] = df_concatenated['AnneePublication'].apply(change_year_format)
df_concatenated['Modified'] = df_concatenated['Modified'].astype(str)
df_concatenated['Created'] = df_concatenated['Created'].astype(str)
df_concatenated
# Out:
#                 FileLeafRef ComplianceAssetId Title _ExtendedDescription  \
# 0            DM007747-1.pdf
# 1            DM007783-1.pdf
# 2            DM007798-1.pdf
# 3            DM007808-1.pdf
# 4            DM007837-1.pdf
# ...                     ...               ...   ...                  ...
# 55418  EM006305306-0004.pdf
# 55419  EM006305306-0005.pdf
# 55420  EM006306205-0001.pdf
# 55421  EM006309415-0001.pdf
# 55422  EM006309415-0002.pdf
#
#       AnneePublication Commentaires ControlOk CriterisationIncomplete  \
# 0                 1987                     No                      No
# 1                 1987                     No                      No
# 2                 1987                     No                      No
# 3                 1987                     No                      No
# 4                 1987                     No                      No
# ...                ...          ...       ...                     ...
# 55418             2019                     No                      No
# 55419             2019                     No                      No
# 55420             2019                     No                      No
# 55421             2019                     No                      No
# 55422             2019                     No                      No
#
#       CriterisationOK                                QueVoyezVousBottles  ...  \
# 0                 Yes  Shoulder|Trapeze|Rounded Edges|Cylinder|Oval|H...  ...
# 1                 Yes  Packaging|Triangle|Hanger|Cylinder|Cube Rectan...  ...
# 2                 Yes   Cylinder|Ring|Bottle base|Rounded Rectangle|Oval  ...
# 3                 Yes  Hemisphere|Curved|Flattened sphere|Opaque|red|...  ...
# 4                 Yes                Octagonal|Hanger|Barrel|Bottle base  ...
# ...               ...                                                ...  ...
# 55418             Yes     Cylinder|Striated|Cone|Digging|Waviness|Flower  ...
# 55419             Yes     Cylinder|Striated|Cone|Digging|Waviness|Flower  ...
# 55420             Yes  Characters / Anatomy|Opaque|integrated / Conti...  ...
# 55421             Yes  Rectangular|label|Phrase-writing|Transparent|C...  ...
# 55422             Yes  Rectangular|label|Transparent|Cylinder|black|S...  ...
#
#       _ComplianceTagWrittenTime _ComplianceTagUserId _CommentCount _LikeCount  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                  ...           ...        ...
# 55418
# 55419
# 55420
# 55421
# 55422
#
#       _DisplayName AppAuthor AppEditor _UIVersionString ParentVersionString  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...            ...       ...       ...              ...                 ...
# 55418                                               1.0
# 55419                                               1.0
# 55420                                               1.0
# 55421                                               1.0
# 55422                                               1.0
#
#        ParentLeafName
# 0
# 1
# 2
# 3
# 4
# ...               ...
# 55418
# 55419
# 55420
# 55421
# 55422
#
# [55423 rows x 40 columns]

# %%
remaining_columns = ['FileLeafRef', 'AnneePublication', 'QueVoyezVousBottles',
       'OUBottles', 'MatiereBottles', 'Modified', 'Depot',  'Created', 'Author', 'Editor', 'Region']
depot_region_mappings = {
    "CN": 'Chine',
    "HK": 'Hong Kong',
    "IFPI": 'Suisse',
    "INPI": 'France',
    "OHMI": 'UE',
    "OMPI": 'Monde',
    "USPTO": 'USA',
    "": ''
}
df_concatenated['Region'] = df_concatenated['Depot'].map(depot_region_mappings)


df_concatenated = df_concatenated[remaining_columns]
df_concatenated
# Out:
#                 FileLeafRef AnneePublication  \
# 0            DM007747-1.pdf             1987
# 1            DM007783-1.pdf             1987
# 2            DM007798-1.pdf             1987
# 3            DM007808-1.pdf             1987
# 4            DM007837-1.pdf             1987
# ...                     ...              ...
# 55418  EM006305306-0004.pdf             2019
# 55419  EM006305306-0005.pdf             2019
# 55420  EM006306205-0001.pdf             2019
# 55421  EM006309415-0001.pdf             2019
# 55422  EM006309415-0002.pdf             2019
#
#                                      QueVoyezVousBottles       OUBottles  \
# 0      Shoulder|Trapeze|Rounded Edges|Cylinder|Oval|H...  body|plug|neck
# 1      Packaging|Triangle|Hanger|Cylinder|Cube Rectan...       body|plug
# 2       Cylinder|Ring|Bottle base|Rounded Rectangle|Oval       body|plug
# 3      Hemisphere|Curved|Flattened sphere|Opaque|red|...       body|plug
# 4                    Octagonal|Hanger|Barrel|Bottle base       body|plug
# ...                                                  ...             ...
# 55418     Cylinder|Striated|Cone|Digging|Waviness|Flower       body|plug
# 55419     Cylinder|Striated|Cone|Digging|Waviness|Flower       body|plug
# 55420  Characters / Anatomy|Opaque|integrated / Conti...       body|plug
# 55421  Rectangular|label|Phrase-writing|Transparent|C...       body|plug
# 55422  Rectangular|label|Transparent|Cylinder|black|S...       body|plug
#
#       MatiereBottles             Modified Depot          Created  \
# 0                     2022-12-04 13:52:00  OMPI   8/1/2018 17:31
# 1                     2022-12-04 13:52:00  OMPI   8/1/2018 17:31
# 2                     2022-12-04 13:52:00  OMPI   8/1/2018 17:31
# 3                     2022-12-04 13:52:00  OMPI   8/1/2018 17:31
# 4                     2022-12-04 13:52:00  OMPI   8/1/2018 17:31
# ...              ...                  ...   ...              ...
# 55418                 2022-12-04 20:12:00  OHMI  2/19/2020 16:34
# 55419                 2022-12-04 20:12:00  OHMI  2/19/2020 16:34
# 55420                 2022-12-04 20:12:00  OHMI  2/19/2020 16:34
# 55421          Glass  2022-12-04 20:12:00  OHMI  2/19/2020 16:34
# 55422          Glass  2022-12-04 20:12:00  OHMI  2/19/2020 16:34
#
#                           Author          Editor Region
# 0      Brahim Ouarahmane Griffes  Support Redsen  Monde
# 1      Brahim Ouarahmane Griffes  Support Redsen  Monde
# 2      Brahim Ouarahmane Griffes  Support Redsen  Monde
# 3      Brahim Ouarahmane Griffes  Support Redsen  Monde
# 4      Brahim Ouarahmane Griffes  Support Redsen  Monde
# ...                          ...             ...    ...
# 55418  Brahim Ouarahmane Griffes  Support Redsen     UE
# 55419  Brahim Ouarahmane Griffes  Support Redsen     UE
# 55420  Brahim Ouarahmane Griffes  Support Redsen     UE
# 55421  Brahim Ouarahmane Griffes  Support Redsen     UE
# 55422  Brahim Ouarahmane Griffes  Support Redsen     UE
#
# [55423 rows x 11 columns]

# %%
file_path = 'Downloads/original_metadata.xlsx'

# Read the Excel file
df_bottles_metadata = pd.read_excel(file_path, sheet_name='Bottles')
df_bottles_metadata = df_bottles_metadata[['Level 0', 'Level 1', 'Level 2', 'Level 3', 'Alias Catalog']].fillna('')
df_bottles_metadata
# Out:
#      Level 0         Level 1              Level 2                Level 3  \
# 0    Bottles         Matiere            Cardboard
# 1    Bottles         Matiere  Composite materials
# 2    Bottles         Matiere                Glass
# 3    Bottles         Matiere                Metal
# 4    Bottles         Matiere             Plastics
# ..       ...             ...                  ...                    ...
# 277  Bottles  Que voyez vous                Other                 Weapon
# 278  Bottles  Que voyez vous                Other                  Wheel
# 279  Bottles  Que voyez vous                Other                   Wing
# 280  Bottles  Que voyez vous                Other  World Map / Territory
# 281  Bottles  Que voyez vous                Other                 Zodiac
#
#            Alias Catalog
# 0         MatiereBottles
# 1         MatiereBottles
# 2         MatiereBottles
# 3         MatiereBottles
# 4         MatiereBottles
# ..                   ...
# 277  QueVoyezVousBottles
# 278  QueVoyezVousBottles
# 279  QueVoyezVousBottles
# 280  QueVoyezVousBottles
# 281  QueVoyezVousBottles
#
# [282 rows x 5 columns]

# %%
def concatenate_strings(row, columns):
    list_strings = [row[col] for col in columns if row[col]][:-1]
    return '.'.join(list_strings).lower()

# %%
level_columns = ['Level 0', 'Level 1', 'Level 2', 'Level 3']
df_bottles_metadata['paths'] = df_bottles_metadata.apply(lambda row: concatenate_strings(row, level_columns), axis=1)
df_bottles_metadata
# Out:
#      Level 0         Level 1              Level 2                Level 3  \
# 0    Bottles         Matiere            Cardboard
# 1    Bottles         Matiere  Composite materials
# 2    Bottles         Matiere                Glass
# 3    Bottles         Matiere                Metal
# 4    Bottles         Matiere             Plastics
# ..       ...             ...                  ...                    ...
# 277  Bottles  Que voyez vous                Other                 Weapon
# 278  Bottles  Que voyez vous                Other                  Wheel
# 279  Bottles  Que voyez vous                Other                   Wing
# 280  Bottles  Que voyez vous                Other  World Map / Territory
# 281  Bottles  Que voyez vous                Other                 Zodiac
#
#            Alias Catalog                         paths
# 0         MatiereBottles               bottles.matiere
# 1         MatiereBottles               bottles.matiere
# 2         MatiereBottles               bottles.matiere
# 3         MatiereBottles               bottles.matiere
# 4         MatiereBottles               bottles.matiere
# ..                   ...                           ...
# 277  QueVoyezVousBottles  bottles.que voyez vous.other
# 278  QueVoyezVousBottles  bottles.que voyez vous.other
# 279  QueVoyezVousBottles  bottles.que voyez vous.other
# 280  QueVoyezVousBottles  bottles.que voyez vous.other
# 281  QueVoyezVousBottles  bottles.que voyez vous.other
#
# [282 rows x 6 columns]

# %%
metadata_mapping = df_bottles_metadata[['Alias Catalog', 'paths']].drop_duplicates()
metadata_mapping
# Out:
#            Alias Catalog                                         paths
# 0         MatiereBottles                               bottles.matiere
# 6              OUBottles                                    bottles.ou
# 10   QueVoyezVousBottles                  bottles.que voyez vous.other
# 14   QueVoyezVousBottles         bottles.que voyez vous.animal / fauna
# 49   QueVoyezVousBottles   bottles.que voyez vous.characters / anatomy
# 65   QueVoyezVousBottles                  bottles.que voyez vous.color
# 104  QueVoyezVousBottles        bottles.que voyez vous.geometric shape
# 151  QueVoyezVousBottles  bottles.que voyez vous.landscape / vegetable
# 179  QueVoyezVousBottles                bottles.que voyez vous.objects
# 220  QueVoyezVousBottles                  bottles.que voyez vous.sport
# 227  QueVoyezVousBottles              bottles.que voyez vous.structure

# %%
d = {'Alias Catalog': ['AnneePublication', 'Modified', 'Created', 'Depot', 'Author', 'Editor', 'FileLeafRef', 'Region'], 
     'paths': ['year', 'modified', 'created', 'depot', 'author', 'editor', 'filename', 'region']}

df_structu_metadata = pd.DataFrame(data=d)
df_structu_metadata
# Out:
#       Alias Catalog     paths
# 0  AnneePublication      year
# 1          Modified  modified
# 2           Created   created
# 3             Depot     depot
# 4            Author    author
# 5            Editor    editor
# 6       FileLeafRef  filename
# 7            Region    region

# %%
metadata_names_df = pd.concat([df_structu_metadata, metadata_mapping], ignore_index=True)
metadata_names_df
# Out:
#           Alias Catalog                                         paths
# 0      AnneePublication                                          year
# 1              Modified                                      modified
# 2               Created                                       created
# 3                 Depot                                         depot
# 4                Author                                        author
# 5                Editor                                        editor
# 6           FileLeafRef                                      filename
# 7                Region                                        region
# 8        MatiereBottles                               bottles.matiere
# 9             OUBottles                                    bottles.ou
# 10  QueVoyezVousBottles                  bottles.que voyez vous.other
# 11  QueVoyezVousBottles         bottles.que voyez vous.animal / fauna
# 12  QueVoyezVousBottles   bottles.que voyez vous.characters / anatomy
# 13  QueVoyezVousBottles                  bottles.que voyez vous.color
# 14  QueVoyezVousBottles        bottles.que voyez vous.geometric shape
# 15  QueVoyezVousBottles  bottles.que voyez vous.landscape / vegetable
# 16  QueVoyezVousBottles                bottles.que voyez vous.objects
# 17  QueVoyezVousBottles                  bottles.que voyez vous.sport
# 18  QueVoyezVousBottles              bottles.que voyez vous.structure

# %%
metadata_names_dict = dict(zip(metadata_names_df['Alias Catalog'], metadata_names_df['paths']))
del metadata_names_dict['QueVoyezVousBottles']  
metadata_names_dict
# Out:
# {'AnneePublication': 'year',
#  'Modified': 'modified',
#  'Created': 'created',
#  'Depot': 'depot',
#  'Author': 'author',
#  'Editor': 'editor',
#  'FileLeafRef': 'filename',
#  'Region': 'region',
#  'MatiereBottles': 'bottles.matiere',
#  'OUBottles': 'bottles.ou'}

# %%
quevoyez_val_maps_df = df_bottles_metadata[df_bottles_metadata['Level 1'] == 'Que voyez vous'][['Level 3', 'paths']].groupby('Level 3')['paths'].agg(list).reset_index()
quevoyez_value_mappings = dict(zip(quevoyez_val_maps_df['Level 3'], quevoyez_val_maps_df['paths']))
quevoyez_value_mappings
# Out:
# {'Airplane': ['bottles.que voyez vous.other'],
#  'Airplane Wing': ['bottles.que voyez vous.other'],
#  'Amulet': ['bottles.que voyez vous.other'],
#  'Anchor': ['bottles.que voyez vous.objects'],
#  'Angel / Demon': ['bottles.que voyez vous.other'],
#  'Arch': ['bottles.que voyez vous.geometric shape'],
#  'Architecture / Monument': ['bottles.que voyez vous.other'],
#  'Arrow': ['bottles.que voyez vous.objects'],
#  'Asymmetrical': ['bottles.que voyez vous.geometric shape'],
#  'Automobile': ['bottles.que voyez vous.other'],
#  'Bag / Pocket': ['bottles.que voyez vous.other'],
#  'Balance': ['bottles.que voyez vous.other'],
#  'Band': ['bottles.que voyez vous.other'],
#  'Barrel': ['bottles.que voyez vous.geometric shape'],
#  'Basket': ['bottles.que voyez vous.sport'],
#  'Bees': ['bottles.que voyez vous.animal / fauna'],
#  'Beige': ['bottles.que voyez vous.color'],
#  'Bell': ['bottles.que voyez vous.other'],
#  'Belt': ['bottles.que voyez vous.other'],
#  'Beveling': ['bottles.que voyez vous.other'],
#  'Birds': ['bottles.que voyez vous.animal / fauna'],
#  'Bottle': ['bottles.que voyez vous.other',
#   'bottles.que voyez vous.structure'],
#  'Bottle base': ['bottles.que voyez vous.other'],
#  'Bougie': ['bottles.que voyez vous.other'],
#  'Braided': ['bottles.que voyez vous.other'],
#  'Brown': ['bottles.que voyez vous.color'],
#  'Brushes': ['bottles.que voyez vous.other'],
#  'Butterfly': ['bottles.que voyez vous.animal / fauna'],
#  'Button': ['bottles.que voyez vous.other'],
#  'Cable': ['bottles.que voyez vous.structure'],
#  'Cabochon': ['bottles.que voyez vous.other'],
#  'Cage': ['bottles.que voyez vous.other'],
#  'Cameoes': ['bottles.que voyez vous.geometric shape'],
#  'Cannage': ['bottles.que voyez vous.other'],
#  'Caps': ['bottles.que voyez vous.other'],
#  'Capsule': ['bottles.que voyez vous.geometric shape'],
#  'Cartoon cartoon': ['bottles.que voyez vous.characters / anatomy'],
#  'Casino / Games': ['bottles.que voyez vous.other'],
#  'Chain': ['bottles.que voyez vous.other'],
#  'Charm': ['bottles.que voyez vous.other'],
#  'Checkerboard': ['bottles.que voyez vous.objects'],
#  'Chiselled/notched': ['bottles.que voyez vous.structure'],
#  'Circle': ['bottles.que voyez vous.geometric shape'],
#  'Claws': ['bottles.que voyez vous.other'],
#  'Clip': ['bottles.que voyez vous.other'],
#  'Clothing': ['bottles.que voyez vous.other'],
#  'Clou': ['bottles.que voyez vous.other'],
#  'Cloud': ['bottles.que voyez vous.other'],
#  'Compartment': ['bottles.que voyez vous.other'],
#  'Concentric': ['bottles.que voyez vous.structure'],
#  'Cone': ['bottles.que voyez vous.other'],
#  'Cooking': ['bottles.que voyez vous.other'],
#  'Cotte De Maille': ['bottles.que voyez vous.other'],
#  'Couture': ['bottles.que voyez vous.other'],
#  'Covered': ['bottles.que voyez vous.other'],
#  'Creneau': ['bottles.que voyez vous.structure'],
#  'Crosses': ['bottles.que voyez vous.geometric shape'],
#  'Crown': ['bottles.que voyez vous.other'],
#  'Cube': ['bottles.que voyez vous.geometric shape'],
#  'Cube Rectangle': ['bottles.que voyez vous.other'],
#  'Cube Square': ['bottles.que voyez vous.other'],
#  'Curved': ['bottles.que voyez vous.other'],
#  'Cushion': ['bottles.que voyez vous.geometric shape'],
#  'Cylinder': ['bottles.que voyez vous.geometric shape'],
#  'Demi cercle': ['bottles.que voyez vous.other'],
#  'Diamond': ['bottles.que voyez vous.geometric shape'],
#  'Diamond Shape': ['bottles.que voyez vous.other'],
#  'Digging': ['bottles.que voyez vous.structure'],
#  'Disc/amulette': ['bottles.que voyez vous.objects'],
#  'Dragon': ['bottles.que voyez vous.animal / fauna'],
#  'Dragonfly': ['bottles.que voyez vous.animal / fauna'],
#  'Drapé': ['bottles.que voyez vous.other'],
#  'Drop': ['bottles.que voyez vous.geometric shape'],
#  'Earth': ['bottles.que voyez vous.landscape / vegetable'],
#  'Electrical fuse': ['bottles.que voyez vous.objects'],
#  'Enveloppe': ['bottles.que voyez vous.other'],
#  'Eye': ['bottles.que voyez vous.characters / anatomy'],
#  'Fabrics': ['bottles.que voyez vous.other'],
#  'Faceted': ['bottles.que voyez vous.structure'],
#  'Fade out': ['bottles.que voyez vous.geometric shape'],
#  'Faucet': ['bottles.que voyez vous.other'],
#  'Feather': ['bottles.que voyez vous.animal / fauna'],
#  'Fer à cheval': ['bottles.que voyez vous.other'],
#  'Fermoir': ['bottles.que voyez vous.other'],
#  'Feu': ['bottles.que voyez vous.other'],
#  'Figure': ['bottles.que voyez vous.other'],
#  'Fish': ['bottles.que voyez vous.animal / fauna'],
#  'Flag': ['bottles.que voyez vous.other'],
#  'Flattened sphere': ['bottles.que voyez vous.geometric shape'],
#  'Flower': ['bottles.que voyez vous.landscape / vegetable'],
#  'Foot': ['bottles.que voyez vous.characters / anatomy',
#   'bottles.que voyez vous.sport'],
#  'Franges': ['bottles.que voyez vous.other'],
#  'Fruit': ['bottles.que voyez vous.landscape / vegetable'],
#  'Games': ['bottles.que voyez vous.other'],
#  'Gold': ['bottles.que voyez vous.color'],
#  'Golf': ['bottles.que voyez vous.sport'],
#  'Grappe': ['bottles.que voyez vous.other'],
#  'Grating': ['bottles.que voyez vous.characters / anatomy',
#   'bottles.que voyez vous.structure'],
#  'Grenada': ['bottles.que voyez vous.other'],
#  'Grid / Fragmentation': ['bottles.que voyez vous.other'],
#  'Half capsule': ['bottles.que voyez vous.geometric shape'],
#  'Hammered': ['bottles.que voyez vous.structure'],
#  'Hand': ['bottles.que voyez vous.characters / anatomy'],
#  'Handle': ['bottles.que voyez vous.other'],
#  'Hanger': ['bottles.que voyez vous.geometric shape'],
#  'Heart': ['bottles.que voyez vous.geometric shape'],
#  'Heaven': ['bottles.que voyez vous.landscape / vegetable'],
#  'Hemisphere': ['bottles.que voyez vous.other'],
#  'Heptagon': ['bottles.que voyez vous.geometric shape'],
#  'Hexagonal': ['bottles.que voyez vous.geometric shape'],
#  'Honeycomb': ['bottles.que voyez vous.characters / anatomy'],
#  'Hook': ['bottles.que voyez vous.objects'],
#  'Hourglass': ['bottles.que voyez vous.other'],
#  'Insect': ['bottles.que voyez vous.animal / fauna'],
#  'Insert': ['bottles.que voyez vous.other'],
#  'Interlaced/intertwined': ['bottles.que voyez vous.geometric shape'],
#  'Keel': ['bottles.que voyez vous.geometric shape'],
#  'Key': ['bottles.que voyez vous.other'],
#  'Lace': ['bottles.que voyez vous.characters / anatomy'],
#  'Ladybugs': ['bottles.que voyez vous.animal / fauna'],
#  'Lamp': ['bottles.que voyez vous.other'],
#  'Lemonade stopper': ['bottles.que voyez vous.other'],
#  'Letter': ['bottles.que voyez vous.other'],
#  'Light up': ['bottles.que voyez vous.other'],
#  'Lighter': ['bottles.que voyez vous.other'],
#  'Lighthouse': ['bottles.que voyez vous.other'],
#  'Lipstick': ['bottles.que voyez vous.other'],
#  'Logo': ['bottles.que voyez vous.other'],
#  'Match': ['bottles.que voyez vous.objects'],
#  'Media TV, telephone, camera': ['bottles.que voyez vous.other'],
#  'Mesh rib': ['bottles.que voyez vous.characters / anatomy'],
#  'Metal plate': ['bottles.que voyez vous.other'],
#  'Mobile': ['bottles.que voyez vous.other'],
#  'Money': ['bottles.que voyez vous.other'],
#  'Monument': ['bottles.que voyez vous.other'],
#  'Moon': ['bottles.que voyez vous.landscape / vegetable'],
#  'Mountain': ['bottles.que voyez vous.landscape / vegetable'],
#  'Mozaique': ['bottles.que voyez vous.other'],
#  'Music': ['bottles.que voyez vous.other'],
#  'Nautical': ['bottles.que voyez vous.other'],
#  'Node': ['bottles.que voyez vous.objects',
#   'bottles.que voyez vous.structure'],
#  'NotchV': ['bottles.que voyez vous.geometric shape'],
#  'Nuts/screws': ['bottles.que voyez vous.objects'],
#  'Oat grains / rice': ['bottles.que voyez vous.landscape / vegetable'],
#  'Octagonal': ['bottles.que voyez vous.geometric shape'],
#  'Opaque': ['bottles.que voyez vous.other'],
#  'Oval': ['bottles.que voyez vous.geometric shape'],
#  'Packaging': ['bottles.que voyez vous.other'],
#  'Padlocks': ['bottles.que voyez vous.objects'],
#  'Paillettes': ['bottles.que voyez vous.other'],
#  'Panier': ['bottles.que voyez vous.other'],
#  'Panther': ['bottles.que voyez vous.animal / fauna'],
#  'Partial round/Partial round': ['bottles.que voyez vous.geometric shape'],
#  'Paving': ['bottles.que voyez vous.structure'],
#  'Peacock': ['bottles.que voyez vous.animal / fauna'],
#  'Pearl': ['bottles.que voyez vous.structure'],
#  'Pen': ['bottles.que voyez vous.other'],
#  'Pentagon': ['bottles.que voyez vous.geometric shape'],
#  'Petal': ['bottles.que voyez vous.other'],
#  'Photo': ['bottles.que voyez vous.characters / anatomy'],
#  'Phrase-writing': ['bottles.que voyez vous.other'],
#  'Pink': ['bottles.que voyez vous.color'],
#  'Planets': ['bottles.que voyez vous.landscape / vegetable'],
#  'Plastics': ['bottles.que voyez vous.structure'],
#  'Pocket': ['bottles.que voyez vous.other'],
#  'Polygon': ['bottles.que voyez vous.geometric shape'],
#  'Protects the cap': ['bottles.que voyez vous.other'],
#  'Protubeance': ['bottles.que voyez vous.other'],
#  'Pumpon': ['bottles.que voyez vous.structure'],
#  'Pusher (Push-plug)': ['bottles.que voyez vous.objects'],
#  'Puzzle': ['bottles.que voyez vous.other'],
#  'Pyramid': ['bottles.que voyez vous.geometric shape'],
#  'Pyramid-aspect': ['bottles.que voyez vous.other'],
#  'Radius': ['bottles.que voyez vous.other'],
#  'Rasoir': ['bottles.que voyez vous.other'],
#  'Rectangular': ['bottles.que voyez vous.geometric shape'],
#  'Relief': ['bottles.que voyez vous.structure'],
#  'Rim': ['bottles.que voyez vous.other'],
#  'Ring': ['bottles.que voyez vous.other'],
#  'Rivet': ['bottles.que voyez vous.other'],
#  'Rope - Twine - Ribbon': ['bottles.que voyez vous.other'],
#  'Rounded Edges': ['bottles.que voyez vous.other'],
#  'Rounded Rectangle': ['bottles.que voyez vous.geometric shape'],
#  'Row 4': ['bottles.que voyez vous.structure'],
#  'Row 5': ['bottles.que voyez vous.structure'],
#  'Row 6plus': ['bottles.que voyez vous.structure'],
#  'Row2': ['bottles.que voyez vous.structure'],
#  'Row3': ['bottles.que voyez vous.structure'],
#  'Saucer': ['bottles.que voyez vous.other'],
#  'Scale': ['bottles.que voyez vous.structure'],
#  'Scratches': ['bottles.que voyez vous.structure'],
#  'Screw pitch = thread': ['bottles.que voyez vous.structure'],
#  'Screws': ['bottles.que voyez vous.other'],
#  'Segment': ['bottles.que voyez vous.other'],
#  'Sequin': ['bottles.que voyez vous.structure'],
#  'Serious': ['bottles.que voyez vous.structure'],
#  'Shaft': ['bottles.que voyez vous.landscape / vegetable'],
#  'Shamrock': ['bottles.que voyez vous.landscape / vegetable'],
#  'Sheet of paper': ['bottles.que voyez vous.landscape / vegetable'],
#  'Shellfish': ['bottles.que voyez vous.animal / fauna',
#   'bottles.que voyez vous.other'],
#  'Shoulder': ['bottles.que voyez vous.other'],
#  'Silver': ['bottles.que voyez vous.color'],
#  'Skeleton': ['bottles.que voyez vous.animal / fauna'],
#  'Smooth': ['bottles.que voyez vous.structure'],
#  'Snake': ['bottles.que voyez vous.animal / fauna'],
#  'Snow': ['bottles.que voyez vous.other'],
#  'Spatial': ['bottles.que voyez vous.other'],
#  'Special Rod': ['bottles.que voyez vous.other'],
#  'Spherical': ['bottles.que voyez vous.geometric shape'],
#  'Spiral': ['bottles.que voyez vous.geometric shape'],
#  'Spout': ['bottles.que voyez vous.other'],
#  'Square': ['bottles.que voyez vous.geometric shape'],
#  'Staircase': ['bottles.que voyez vous.structure'],
#  'Staple': ['bottles.que voyez vous.other'],
#  'Star': ['bottles.que voyez vous.geometric shape'],
#  'Stone': ['bottles.que voyez vous.other'],
#  'Strata': ['bottles.que voyez vous.structure'],
#  'Striated': ['bottles.que voyez vous.structure'],
#  'Sunshine': ['bottles.que voyez vous.landscape / vegetable',
#   'bottles.que voyez vous.other'],
#  'Support': ['bottles.que voyez vous.other'],
#  'Sword': ['bottles.que voyez vous.other'],
#  'Symbol': ['bottles.que voyez vous.other'],
#  'Syringe': ['bottles.que voyez vous.other'],
#  'Tennis': ['bottles.que voyez vous.sport'],
#  'Threading': ['bottles.que voyez vous.structure'],
#  'Timbre': ['bottles.que voyez vous.other'],
#  'Tire-Bouchon': ['bottles.que voyez vous.other'],
#  "Toile d'araignée": ['bottles.que voyez vous.other'],
#  'Tower': ['bottles.que voyez vous.structure'],
#  'Transparent': ['bottles.que voyez vous.characters / anatomy'],
#  'Trapeze': ['bottles.que voyez vous.other'],
#  'Triangle': ['bottles.que voyez vous.geometric shape'],
#  'Trigger': ['bottles.que voyez vous.other'],
#  'Tubular': ['bottles.que voyez vous.geometric shape'],
#  'Twisted': ['bottles.que voyez vous.structure'],
#  'Vegetable': ['bottles.que voyez vous.other'],
#  'Ventilateur': ['bottles.que voyez vous.other'],
#  'Watch': ['bottles.que voyez vous.other'],
#  'Wave / Wave': ['bottles.que voyez vous.other'],
#  'Waviness': ['bottles.que voyez vous.structure'],
#  'Wax-Seal': ['bottles.que voyez vous.other'],
#  'Weapon': ['bottles.que voyez vous.other'],
#  'Wheel': ['bottles.que voyez vous.other'],
#  'Wing': ['bottles.que voyez vous.other'],
#  'Wood': ['bottles.que voyez vous.structure'],
#  'World Map / Territory': ['bottles.que voyez vous.other'],
#  'Zebra': ['bottles.que voyez vous.animal / fauna'],
#  'Zodiac': ['bottles.que voyez vous.other'],
#  'black': ['bottles.que voyez vous.color'],
#  'blue': ['bottles.que voyez vous.color'],
#  'fabrics': ['bottles.que voyez vous.structure'],
#  'fan': ['bottles.que voyez vous.other'],
#  'fish scale': ['bottles.que voyez vous.other'],
#  'green': ['bottles.que voyez vous.color'],
#  'grey': ['bottles.que voyez vous.color'],
#  'integrated / Continuity': ['bottles.que voyez vous.other'],
#  'label': ['bottles.que voyez vous.other'],
#  'nipple': ['bottles.que voyez vous.other'],
#  'orange': ['bottles.que voyez vous.color'],
#  'painting': ['bottles.que voyez vous.other'],
#  'pattern - topic': ['bottles.que voyez vous.other'],
#  'pierced': ['bottles.que voyez vous.other'],
#  'purple': ['bottles.que voyez vous.color'],
#  'red': ['bottles.que voyez vous.color'],
#  'white': ['bottles.que voyez vous.color'],
#  'yellow': ['bottles.que voyez vous.color']}

# %%
def merge_dictionaries(list_of_dicts):
    merged_dicts = {}
    for d in list_of_dicts:
        if d['filterId'] in merged_dicts:
            # Extend the list of values if the path is already present
            merged_dicts[d['filterId']].extend(d['values'])
        else:
            # Otherwise, add the new path and its values
            merged_dicts[d['filterId']] = d['values']
    # Remove duplicates from the values lists
    for path, values in merged_dicts.items():
        merged_dicts[path] = list(set(values))
    # Convert the merged dictionary back to a list of dictionaries
    merged_list_of_dicts = [{'filterId': path, 'values': values} for path, values in merged_dicts.items()]
    return merged_list_of_dicts

# %%
def get_filter_values(row, metadata_names_dict, quevoyez_value_mappings, cols_filter_values, cols_struct_metadata):
    dict_file = {}
    list_filter_values_paths = []
    for column in cols_struct_metadata:
        dict_file[metadata_names_dict[column]] = row[column]
    for column in cols_filter_values:
        values_taken = row[column]
        if values_taken != '':
            if column != 'QueVoyezVousBottles':
                filter_path = metadata_names_dict[column]
                list_values = values_taken.split('|')
                list_filter_values_paths.append({'filterId': filter_path, 
                                                 'values': list_values})
            else:
                dict_path_qvv = {}
                list_values = values_taken.split('|')
                for value_qvv in list_values:
                    try:
                        path_qvv = quevoyez_value_mappings[value_qvv][0]
                        if path_qvv not in dict_path_qvv.keys():
                            dict_path_qvv[path_qvv] = [value_qvv]
                        else:
                            dict_path_qvv[path_qvv] = dict_path_qvv[path_qvv] + [value_qvv]
                            for filter_path in dict_path_qvv.keys():
                                list_filter_values_paths.append({'filterId': filter_path, 
                                                                 'values': dict_path_qvv[filter_path]})
                    except KeyError:
                        print(f"The value {value_qvv} found in the file {row['FileLeafRef']} does not exist in the metadata.")
    list_filter_values_paths = merge_dictionaries(list_filter_values_paths)
    dict_file['filterValues'] = list_filter_values_paths
    return dict_file
        

columns_filter_values = [ 'QueVoyezVousBottles', 'OUBottles', 'MatiereBottles',]
columns_struct_metadata = ['FileLeafRef', 'AnneePublication', 'Modified', 'Depot', 'Created', 'Author', 'Editor', 'Region']
df_concatenated['dict_filter_values'] = df_concatenated.apply(lambda row: get_filter_values(row, 
                                                                                            metadata_names_dict, 
                                                                                            quevoyez_value_mappings,
                                                                                            columns_filter_values,
                                                                                            columns_struct_metadata), axis=1)
# Out:
# The value Landscape / Vegetable found in the file DM008254-1.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM008254-2.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM008254-3.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM008254-4.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM008385-1.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM008671-1.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM008671-2.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM008671-3.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM008671-4.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM008961-1.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM008961-2.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM009598-1.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM009598-2.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM009760-1.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM009760-2.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM010606-1.pdf does not exist in the metadata.
# The value Objects found in the file DM010711-1.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM010922-1.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM010922-2.pdf does not exist in the metadata.
# The value Objects found in the file DM010963-1.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM010990-1.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM010990-2.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM010990-3.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM010990-4.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM012051-1.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM012408-1.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM012818-1.pdf does not exist in the metadata.
# The value Sport found in the file DM013217-1.pdf does not exist in the metadata.
# The value Sport found in the file DM013217-2.pdf does not exist in the metadata.
# The value Sport found in the file DM013217-3.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM013742-2.pdf does not exist in the metadata.
# The value Sport found in the file DM014089-1.pdf does not exist in the metadata.
# The value Sport found in the file DM014912-1.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-1.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-2.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-3.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-4.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-5.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-6.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-7.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM014913-9.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM015219-1.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file DM015219-1.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file DM015388-1.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file DM015397-1.pdf does not exist in the metadata.
# The value Sport found in the file DM015430-1.pdf does not exist in the metadata.
# The value Sport found in the file DM015430-10.pdf does not exist in the metadata.
# The value Sport found in the file DM015430-11.pdf does not exist in the metadata.
# The value Sport found in the file DM015430-12.pdf does not exist in the metadata.
# The value Sport found in the file DM015430-13.pdf does not exist in the metadata.
# The value Sport found in the file DM015430-14.pdf does not exist in the metadata.
# The value Sport found in the file DM015430-15.pdf does not exist in the metadata.
pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM003821511-0019.pdf does not exist in the metadata.
# The value Sport found in the file EM003821511-0020.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM003821511-0020.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM003821511-0021.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM003839596-0001.pdf does not exist in the metadata.
# The value Sport found in the file EM003839612-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM003876770-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM003876770-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM003877653-0034.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM003877653-0036.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM003877653-0041.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM003991124-0003.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004008779-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004008779-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004008779-0003.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004008886-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004015303-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004046084-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004048866-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004048866-0002.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004048866-0003.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004161404-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004171817-0012.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004171817-0023.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004171817-0035.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004171817-0052.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004171817-0060.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004171817-0072.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004245678-0011.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004245678-0014.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004245678-0015.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004245678-0020.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004378917-0004.pdf does not exist in the metadata.
# The value Sport found in the file EM004379345-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004383966-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004417434-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004498095-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004507085-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004510972-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004538361-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004558260-0007.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004566032-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004592202-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004682631-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004682631-0002.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004682631-0004.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004682631-0005.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004682631-0006.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004707115-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004761641-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004825008-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004838506-0012.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004838506-0013.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004160778-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004160778-0002.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004160778-0003.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004160778-0004.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004160778-0005.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004161404-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004163905-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004163905-0002.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004171817-0012.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004171817-0023.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004171817-0030.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004171817-0034.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004372878-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004372878-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004372878-0003.pdf does not exist in the metadata.
# The value Sport found in the file EM004379345-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM004383966-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004394260-0001.pdf does not exist in the metadata.
# The value Objects found in the file EM004405132-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004406700-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004417434-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004421238-0001.pdf does not exist in the metadata.
# The value Geometric shape found in the file EM004498095-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004507085-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM004510972-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM004513984-0003.pdf does not exist in the metadata.
# The value Sport found in the file EM005229770-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005234887-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005242807-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005246089-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005252806-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005252806-0002.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005253580-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005253861-0001.pdf does not exist in the metadata.
# The value Sport found in the file EM005305083-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005338506-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005338506-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005338506-0003.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005345501-0002.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM005345501-0008.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM005495017-0001.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM005495017-0002.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM005495017-0003.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM005495017-0004.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005501723-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005579521-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005618303-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005618303-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005646858-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005646858-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005646858-0003.pdf does not exist in the metadata.
# The value Sport found in the file EM005653011-0002.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005798154-0001.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005798154-0002.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005798154-0003.pdf does not exist in the metadata.
# The value Animal / Fauna found in the file EM005798154-0004.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005813615-0004.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005888815-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM005888815-0002.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM006080834-0002.pdf does not exist in the metadata.
# The value Landscape / Vegetable found in the file EM006081246-0004.pdf does not exist in the metadata.
# The value Sport found in the file EM006264602-0001.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM006270005-0006.pdf does not exist in the metadata.
# The value Characters / Anatomy found in the file EM006306205-0001.pdf does not exist in the metadata.
# C:\Users\delll\AppData\Local\Temp\ipykernel_4972\2500185387.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concatenated['dict_filter_values'] = df_concatenated.apply(lambda row: get_filter_values(row,

# %%
import json

# Specify the filename
filename = 'bottles_documents_metadata.json'

# Write JSON data to a file
with open(filename, 'w', encoding='utf-8') as file:
    json.dump(list(df_concatenated['dict_filter_values']), file, ensure_ascii=False, indent=4)
